# %% [markdown]
# # 第五次课作业

# %% [markdown]
# （1）读取数据。读取之前作业保存的“酒店数据1.xlsx”

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("酒店数据1.xlsx",index_col = 0)

# %%
df[:5]
# Out:
#                                                名字    类型  城市   地区  \
# 0  香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 1                              香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 2                       香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 3                            如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# 4          香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港   湾仔
#
#               地点   评分   评分人数   价格
# 0       铜锣湾永兴街8号  4.5  12708  693
# 1     九龙旺角洗衣街88号  4.7    328  747
# 2  皇后大道东387-397号  4.4   5014  693
# 3       观塘创业街38号  4.6   3427  581
# 4  铜锣湾边宁顿街13-15号  4.5   1938  869

# %% [markdown]
# （2）将“类型”和“名字”设置为层次化索引，并交换索引的位置。然后将层次化索引取消。

# %%
data = df.set_index(["类型","名字"])
#data = data.swaplevel('名字','类型')
data = data.reset_index()
data
# Out:
#        类型                                                名字  城市    地区  \
# 0    浪漫情侣    香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  香港    东区
# 1    商务出行                                香港碧荟酒店(The BEACON)  香港   油尖旺
# 2    浪漫情侣                         香港湾仔帝盛酒店(Dorsett Wanchai)  香港    湾仔
# 3    浪漫情侣                              如心艾朗酒店(L‘hotel elan)  香港    观塘
# 4    浪漫情侣            香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  香港    湾仔
# ..    ...                                               ...  ..   ...
# 391  地铁周边                                            香港金泉酒店  香港  其他地区
# 392  地铁周边                       香港天天宾馆(TIN TIN GUEST HOUSE)  香港   油尖旺
# 393  海滨风光  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  香港    荃湾
# 394  海滨风光  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  香港    荃湾
# 395  地铁周边                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  香港   油尖旺
#
#                        地点        评分   评分人数   价格
# 0                铜锣湾永兴街8号  4.500000  12708  693
# 1              九龙旺角洗衣街88号  4.700000    328  747
# 2           皇后大道东387-397号  4.400000   5014  693
# 3                观塘创业街38号  4.600000   3427  581
# 4           铜锣湾边宁顿街13-15号  4.500000   1938  869
# ..                    ...       ...    ...  ...
# 391  香港旺角弥敦道607号新兴大厦1407室  4.282973     16  245
# 392    旺角弥敦道607号新兴大厦1517A  3.200000     16  227
# 393              荃湾 杨屋道8号  4.500000  45462  709
# 394              荃湾 杨屋道8号  4.500000  45463  709
# 395   尖沙咀弥敦道87号华源大厦9字楼C2室  4.000000    273  256
#
# [396 rows x 8 columns]

# %% [markdown]
# （3）将数据集转置，获取转制后的index和columns。

# %%
df.T
# Out:
#                                                  0                   1    \
# 名字    香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  香港碧荟酒店(The BEACON)
# 类型                                              浪漫情侣                商务出行
# 城市                                                香港                  香港
# 地区                                                东区                 油尖旺
# 地点                                          铜锣湾永兴街8号          九龙旺角洗衣街88号
# 评分                                               4.5                 4.7
# 评分人数                                           12708                 328
# 价格                                               693                 747
#
#                             2                     3    \
# 名字    香港湾仔帝盛酒店(Dorsett Wanchai)  如心艾朗酒店(L‘hotel elan)
# 类型                         浪漫情侣                  浪漫情侣
# 城市                           香港                    香港
# 地区                           湾仔                    观塘
# 地点                皇后大道东387-397号              观塘创业街38号
# 评分                          4.4                   4.6
# 评分人数                       5014                  3427
# 价格                          693                   581
#
#                                          4    \
# 名字    香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)
# 类型                                      浪漫情侣
# 城市                                        香港
# 地区                                        湾仔
# 地点                             铜锣湾边宁顿街13-15号
# 评分                                       4.5
# 评分人数                                    1938
# 价格                                       869
#
#                                                     5    \
# 名字    海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...
# 类型                                                 海滨风光
# 城市                                                   香港
# 地区                                                  油尖旺
# 地点                                          尖沙咀東部麽地道70号
# 评分                                                  4.7
# 评分人数                                               4366
# 价格                                                 1296
#
#                           6                              7    \
# 名字    香港怡东酒店(Excelsior Hotel)  香港富豪九龙酒店(Regal Kowloon Hotel)
# 类型                       海滨风光                           休闲度假
# 城市                         香港                             香港
# 地区                         湾仔                            油尖旺
# 地点                铜锣湾告士打道281号                      尖沙嘴麽地道71号
# 评分                        4.6                            4.5
# 评分人数                     6961                          11265
# 价格                       1184                            692
#
#                                8                                 9    ...  \
# 名字    港岛香格里拉大酒店(Island Shangri-La)  香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  ...
# 类型                            海滨风光                              地铁周边  ...
# 城市                              香港                                香港  ...
# 地区                             中西区                               油尖旺  ...
# 地点                     金钟中区法院道太古广场            九龙旺角弥敦道607号新兴大厦14楼16单位  ...
# 评分                             4.8                               4.1  ...
# 评分人数                          4182                              1029  ...
# 价格                            2836                               218  ...
#
#                                        386                              387  \
# 名字    香港圣地牙哥宾馆(家庭旅馆)(San Diego Guesthouse)  香港珠峰旅馆(Everest Inn Guest House)
# 类型                                    地铁周边                             地铁周边
# 城市                                      香港                               香港
# 地区                                     油尖旺                             其他地区
# 地点                      亚皆老街83号先施大厦3字楼309室    香港弥敦道40号重庆大厦D座16字楼3室(尖沙咀地铁站旁)
# 评分                                4.282973                         4.282973
# 评分人数                                    84                                7
# 价格                                     348                              175
#
#            388                       389                        390  \
# 名字    深圳月亮月亮公寓   香港航天星际酒店(Hotel Skystar)  香港HotelVenus(Hotel Venus)
# 类型          民宿                      地铁周边                       地铁周边
# 城市          香港                        香港                         香港
# 地区         罗湖区                      其他地区                        油尖旺
# 地点    深圳罗湖区渔民村  尖沙咀弥敦道36-40号重庆大厦E座14楼E3室   尖沙咀弥敦道36-40号重庆大厦C座12楼C6室
# 评分    4.282973                  4.282973                   4.282973
# 评分人数        24                         3                          2
# 价格         506                       172                        172
#
#                        391                          392  \
# 名字                  香港金泉酒店  香港天天宾馆(TIN TIN GUEST HOUSE)
# 类型                    地铁周边                         地铁周边
# 城市                      香港                           香港
# 地区                    其他地区                          油尖旺
# 地点    香港旺角弥敦道607号新兴大厦1407室           旺角弥敦道607号新兴大厦1517A
# 评分                4.282973                          3.2
# 评分人数                    16                           16
# 价格                     245                          227
#
#                                                    393  \
# 名字    香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)
# 类型                                                海滨风光
# 城市                                                  香港
# 地区                                                  荃湾
# 地点                                            荃湾 杨屋道8号
# 评分                                                 4.5
# 评分人数                                             45462
# 价格                                                 709
#
#                                                    394  \
# 名字    香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)
# 类型                                                海滨风光
# 城市                                                  香港
# 地区                                                  荃湾
# 地点                                            荃湾 杨屋道8号
# 评分                                                 4.5
# 评分人数                                             45463
# 价格                                                 709
#
#                              395
# 名字    香港花盈酒店(家庭旅馆)(Bloomy Hotel)
# 类型                          地铁周边
# 城市                            香港
# 地区                           油尖旺
# 地点           尖沙咀弥敦道87号华源大厦9字楼C2室
# 评分                           4.0
# 评分人数                         273
# 价格                           256
#
# [8 rows x 396 columns]

# %% [markdown]
# （4）用Groupby方法来计算每个地区的评分人数的总和以及均值。

# %%
df.评分人数.groupby(df["地区"]).sum()
# Out:
# 地区
# 东区       56643
# 中西区      59682
# 九龙城      49855
# 元朗        1200
# 其他地区     16831
# 南区       12867
# 屯门        7324
# 沙田       39622
# 油尖旺     422574
# 深水埗区        16
# 湾仔      107344
# 离岛       60359
# 罗湖区         24
# 荃湾      114610
# 葵青       11544
# 观塘       19137
# Name: 评分人数, dtype: int64

# %%
df.评分人数.groupby(df["地区"]).mean()
# Out:
# 地区
# 东区       3540.187500
# 中西区      1808.545455
# 九龙城      2374.047619
# 元朗       1200.000000
# 其他地区      300.553571
# 南区       2573.400000
# 屯门       3662.000000
# 沙田       9905.500000
# 油尖旺      2284.183784
# 深水埗区       16.000000
# 湾仔       2618.146341
# 离岛       5487.181818
# 罗湖区        24.000000
# 荃湾      16372.857143
# 葵青       2308.800000
# 观塘       2733.857143
# Name: 评分人数, dtype: float64

# %% [markdown]
# （5）用Grouby方法计算每个类型的平均价格，最高价和最低价。

# %%
df.价格.groupby(df["地区"]).max()
# Out:
# 地区
# 东区       1908
# 中西区     12926
# 九龙城      1742
# 元朗        425
# 其他地区     1450
# 南区        553
# 屯门        696
# 沙田       1052
# 油尖旺      3862
# 深水埗区      648
# 湾仔       2856
# 离岛       1667
# 罗湖区       506
# 荃湾        709
# 葵青        423
# 观塘       1132
# Name: 价格, dtype: int64

# %% [markdown]
# （6）数据离散化，按照价格将酒店分为3个等级,0-500为C，500-1000为B,大于1000为A，列名设置为“价格等级”。

# %%
df['价格等级'] = pd.cut(df['价格'],[0,500,1000,12926],labels = ['C','B','A'] )
df
# Out:
#                                                    名字    类型  城市    地区  \
# 0      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港    东区
# 1                                  香港碧荟酒店(The BEACON)  商务出行  香港   油尖旺
# 2                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港    湾仔
# 3                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港    观塘
# 4              香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港    湾仔
# ..                                                ...   ...  ..   ...
# 391                                            香港金泉酒店  地铁周边  香港  其他地区
# 392                       香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港   油尖旺
# 393  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港    荃湾
# 394  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港    荃湾
# 395                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港   油尖旺
#
#                        地点        评分   评分人数   价格 价格等级
# 0                铜锣湾永兴街8号  4.500000  12708  693    B
# 1              九龙旺角洗衣街88号  4.700000    328  747    B
# 2           皇后大道东387-397号  4.400000   5014  693    B
# 3                观塘创业街38号  4.600000   3427  581    B
# 4           铜锣湾边宁顿街13-15号  4.500000   1938  869    B
# ..                    ...       ...    ...  ...  ...
# 391  香港旺角弥敦道607号新兴大厦1407室  4.282973     16  245    C
# 392    旺角弥敦道607号新兴大厦1517A  3.200000     16  227    C
# 393              荃湾 杨屋道8号  4.500000  45462  709    B
# 394              荃湾 杨屋道8号  4.500000  45463  709    B
# 395   尖沙咀弥敦道87号华源大厦9字楼C2室  4.000000    273  256    C
#
# [396 rows x 9 columns]

# %% [markdown]
# （7）获取评分均值最高和最低的地区的数据，分别使用append和concat方法将获取的两个数据集合并。

# %%
df.评分.groupby(df['地区']).max()
# Out:
# 地区
# 东区      4.700000
# 中西区     4.800000
# 九龙城     4.800000
# 元朗      4.500000
# 其他地区    4.800000
# 南区      4.400000
# 屯门      4.700000
# 沙田      4.700000
# 油尖旺     4.900000
# 深水埗区    4.300000
# 湾仔      4.700000
# 离岛      4.800000
# 罗湖区     4.282973
# 荃湾      4.500000
# 葵青      4.400000
# 观塘      4.600000
# Name: 评分, dtype: float64

# %%
a = df[df['地区']=='油尖旺']
a
# Out:
#                                                     名字    类型  城市   地区  \
# 1                                   香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 5    海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...  海滨风光  香港  油尖旺
# 7                        香港富豪九龙酒店(Regal Kowloon Hotel)  休闲度假  香港  油尖旺
# 9                     香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  地铁周边  香港  油尖旺
# 11                  香港都会海逸酒店(Harbour Plaza Metropolis)  海滨风光  香港  油尖旺
# ..                                                 ...   ...  ..  ...
# 385                                  香港捷舒旅(Just Hotel)  地铁周边  香港  油尖旺
# 386               香港圣地牙哥宾馆(家庭旅馆)(San Diego Guesthouse)  地铁周边  香港  油尖旺
# 390                          香港HotelVenus(Hotel Venus)  地铁周边  香港  油尖旺
# 392                        香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港  油尖旺
# 395                         香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
#
#                            地点        评分   评分人数    价格 价格等级
# 1                  九龙旺角洗衣街88号  4.700000    328   747    B
# 5                 尖沙咀東部麽地道70号  4.700000   4366  1296    A
# 7                   尖沙嘴麽地道71号  4.500000  11265   692    B
# 9      九龙旺角弥敦道607号新兴大厦14楼16单位  4.100000   1029   218    C
# 11                   红磡 都会道7号  4.500000  14872   562    B
# ..                        ...       ...    ...   ...  ...
# 385     尖沙咀金巴利道27-33号永利大厦F座4楼  3.800000    183   888    B
# 386        亚皆老街83号先施大厦3字楼309室  4.282973     84   348    C
# 390  尖沙咀弥敦道36-40号重庆大厦C座12楼C6室  4.282973      2   172    C
# 392        旺角弥敦道607号新兴大厦1517A  3.200000     16   227    C
# 395       尖沙咀弥敦道87号华源大厦9字楼C2室  4.000000    273   256    C
#
# [185 rows x 9 columns]

# %%
b = df[df['地区']=='罗湖区']
b
# Out:
#            名字  类型  城市   地区        地点        评分  评分人数   价格 价格等级
# 388  深圳月亮月亮公寓  民宿  香港  罗湖区  深圳罗湖区渔民村  4.282973    24  506    B

# %%
c = pd.concat([a,b],axis = 0)
c.index = range(len(c))
c
# Out:
#                                                     名字    类型  城市   地区  \
# 0                                   香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 1    海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...  海滨风光  香港  油尖旺
# 2                        香港富豪九龙酒店(Regal Kowloon Hotel)  休闲度假  香港  油尖旺
# 3                     香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  地铁周边  香港  油尖旺
# 4                   香港都会海逸酒店(Harbour Plaza Metropolis)  海滨风光  香港  油尖旺
# ..                                                 ...   ...  ..  ...
# 181               香港圣地牙哥宾馆(家庭旅馆)(San Diego Guesthouse)  地铁周边  香港  油尖旺
# 182                          香港HotelVenus(Hotel Venus)  地铁周边  香港  油尖旺
# 183                        香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港  油尖旺
# 184                         香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
# 185                                           深圳月亮月亮公寓    民宿  香港  罗湖区
#
#                            地点        评分   评分人数    价格 价格等级
# 0                  九龙旺角洗衣街88号  4.700000    328   747    B
# 1                 尖沙咀東部麽地道70号  4.700000   4366  1296    A
# 2                   尖沙嘴麽地道71号  4.500000  11265   692    B
# 3      九龙旺角弥敦道607号新兴大厦14楼16单位  4.100000   1029   218    C
# 4                    红磡 都会道7号  4.500000  14872   562    B
# ..                        ...       ...    ...   ...  ...
# 181        亚皆老街83号先施大厦3字楼309室  4.282973     84   348    C
# 182  尖沙咀弥敦道36-40号重庆大厦C座12楼C6室  4.282973      2   172    C
# 183        旺角弥敦道607号新兴大厦1517A  3.200000     16   227    C
# 184       尖沙咀弥敦道87号华源大厦9字楼C2室  4.000000    273   256    C
# 185                  深圳罗湖区渔民村  4.282973     24   506    B
#
# [186 rows x 9 columns]

# %% [markdown]
# （8）数据离散化，按照评分人数将酒店平均分为3个等级，三个等级的酒店数量尽量保持一致。评分人数最多的为A，最少的为C。列名设置为“热门等级”。

# %%
bins = np.percentile(df["评分人数"], [0,33,66,100]) #获取分位数
df['热门等级'] = pd.cut(df['评分人数'],bins,labels = ['C','B','A'])
df
# Out:
#                                                    名字    类型  城市    地区  \
# 0      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港    东区
# 1                                  香港碧荟酒店(The BEACON)  商务出行  香港   油尖旺
# 2                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港    湾仔
# 3                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港    观塘
# 4              香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港    湾仔
# ..                                                ...   ...  ..   ...
# 391                                            香港金泉酒店  地铁周边  香港  其他地区
# 392                       香港天天宾馆(TIN TIN GUEST HOUSE)  地铁周边  香港   油尖旺
# 393  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港    荃湾
# 394  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港    荃湾
# 395                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港   油尖旺
#
#                        地点        评分   评分人数   价格 价格等级 热门等级
# 0                铜锣湾永兴街8号  4.500000  12708  693    B    A
# 1              九龙旺角洗衣街88号  4.700000    328  747    B    B
# 2           皇后大道东387-397号  4.400000   5014  693    B    A
# 3                观塘创业街38号  4.600000   3427  581    B    A
# 4           铜锣湾边宁顿街13-15号  4.500000   1938  869    B    A
# ..                    ...       ...    ...  ...  ...  ...
# 391  香港旺角弥敦道607号新兴大厦1407室  4.282973     16  245    C    C
# 392    旺角弥敦道607号新兴大厦1517A  3.200000     16  227    C    C
# 393              荃湾 杨屋道8号  4.500000  45462  709    B    A
# 394              荃湾 杨屋道8号  4.500000  45463  709    B    A
# 395   尖沙咀弥敦道87号华源大厦9字楼C2室  4.000000    273  256    C    B
#
# [396 rows x 10 columns]

# %% [markdown]
# （9）选出评分人数为A，价格也为A的酒店数据，计算其平均评分。

# %% [markdown]
# （10）取价格最高的5个酒店的数据，使用stack和unstack方法实现dataframe和Series之间的转换。

# %%
#sort排序 + [:5]

# %% [markdown]
# （11）纵向拆分数据集，分为df1和df2，df1包含名字，类型，城市，地区，df2包含名字，地点，评分，评分人数，价格，价格等级，热门等级。

# %%
df1 = df[['名字','类型','城市','地区']]
df2 = df[['名字','地点','评分','评分人数','价格','价格等级','热门等级']]
df2
# Out:
#                                                    名字                    地点  \
# 0      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)              铜锣湾永兴街8号
# 1                                  香港碧荟酒店(The BEACON)            九龙旺角洗衣街88号
# 2                           香港湾仔帝盛酒店(Dorsett Wanchai)         皇后大道东387-397号
# 3                                如心艾朗酒店(L‘hotel elan)              观塘创业街38号
# 4              香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)         铜锣湾边宁顿街13-15号
# ..                                                ...                   ...
# 391                                            香港金泉酒店  香港旺角弥敦道607号新兴大厦1407室
# 392                       香港天天宾馆(TIN TIN GUEST HOUSE)    旺角弥敦道607号新兴大厦1517A
# 393  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)              荃湾 杨屋道8号
# 394  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)              荃湾 杨屋道8号
# 395                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)   尖沙咀弥敦道87号华源大厦9字楼C2室
#
#            评分   评分人数   价格 价格等级 热门等级
# 0    4.500000  12708  693    B    A
# 1    4.700000    328  747    B    B
# 2    4.400000   5014  693    B    A
# 3    4.600000   3427  581    B    A
# 4    4.500000   1938  869    B    A
# ..        ...    ...  ...  ...  ...
# 391  4.282973     16  245    C    C
# 392  3.200000     16  227    C    C
# 393  4.500000  45462  709    B    A
# 394  4.500000  45463  709    B    A
# 395  4.000000    273  256    C    B
#
# [396 rows x 7 columns]

# %% [markdown]
# （12）将df2按照价格进行排序，重新设置df2的索引。索引值等于价格排名。

# %% [markdown]
# （13）使用merge方法将df1和df2合并。

# %%
pd.merge(df1, df2, how = "inner", on = "名字")
# Out:
#                                                    名字    类型  城市   地区  \
# 0      香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港   东区
# 1                                  香港碧荟酒店(The BEACON)  商务出行  香港  油尖旺
# 2                           香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港   湾仔
# 3                                如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港   观塘
# 4              香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港   湾仔
# ..                                                ...   ...  ..  ...
# 393  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 394  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 395  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 396  香港如心海景酒店暨会议中心(L‘hotel Nina et Convention Centre)  海滨风光  香港   荃湾
# 397                        香港花盈酒店(家庭旅馆)(Bloomy Hotel)  地铁周边  香港  油尖旺
#
#                       地点   评分   评分人数   价格 价格等级 热门等级
# 0               铜锣湾永兴街8号  4.5  12708  693    B    A
# 1             九龙旺角洗衣街88号  4.7    328  747    B    B
# 2          皇后大道东387-397号  4.4   5014  693    B    A
# 3               观塘创业街38号  4.6   3427  581    B    A
# 4          铜锣湾边宁顿街13-15号  4.5   1938  869    B    A
# ..                   ...  ...    ...  ...  ...  ...
# 393             荃湾 杨屋道8号  4.5  45462  709    B    A
# 394             荃湾 杨屋道8号  4.5  45463  709    B    A
# 395             荃湾 杨屋道8号  4.5  45462  709    B    A
# 396             荃湾 杨屋道8号  4.5  45463  709    B    A
# 397  尖沙咀弥敦道87号华源大厦9字楼C2室  4.0    273  256    C    B
#
# [398 rows x 10 columns]

# %% [markdown]
# （14）将合并后的数据集保存数据到“酒店数据2.xlsx”。

# %%
df.to_excel("酒店数据2.xlsx")
